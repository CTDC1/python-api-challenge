# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import datetime

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

weather_api_key
# Out:
# '92b2ff9dbe4f85400c927eb43a04b513'

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 600

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=92b2ff9dbe4f85400c927eb43a04b513
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tongliao
# Processing Record 2 of Set 1 | ilulissat
# Processing Record 3 of Set 1 | margaret river
# Processing Record 4 of Set 1 | kingsbridge
# Processing Record 5 of Set 1 | puerto natales
# Processing Record 6 of Set 1 | kongsvinger
# Processing Record 7 of Set 1 | saipan
# Processing Record 8 of Set 1 | west island
# Processing Record 9 of Set 1 | isafjordur
# Processing Record 10 of Set 1 | waitangi
# Processing Record 11 of Set 1 | ulladulla
# Processing Record 12 of Set 1 | uray
# Processing Record 13 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | dhidhdhoo
# Processing Record 16 of Set 1 | olonkinbyen
# Processing Record 17 of Set 1 | musoma
# Processing Record 18 of Set 1 | az zuwaytinah
# Processing Record 19 of Set 1 | masterton
# Processing Record 20 of Set 1 | conceicao do araguaia
# Processing Record 21 of Set 1 | balqash
# Processing Record 22 of Set 1 | grytviken
# Processing Record 23 of Set 1 | 'ohonua
# City not found. Skipping...
# Processing Record 24 of Set 1 | remire-montjoly
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | mossel bay
# Processing Record 27 of Set 1 | salinas
# Processing Record 28 of Set 1 | port hedland
# Processing Record 29 of Set 1 | port-aux-francais
# Processing Record 30 of Set 1 | jiayuguan
# Processing Record 31 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 32 of Set 1 | poronaysk
# Processing Record 33 of Set 1 | stanley
# Processing Record 34 of Set 1 | edinburgh of the seven seas
# Processing Record 35 of Set 1 | lebu
# Processing Record 36 of Set 1 | ancud
# Processing Record 37 of Set 1 | inirida
# Processing Record 38 of Set 1 | blackmans bay
# Processing Record 39 of Set 1 | nova sintra
# Processing Record 40 of Set 1 | iqaluit
# Processing Record 41 of Set 1 | happy valley-goose bay
# Processing Record 42 of Set 1 | bethel
# Processing Record 43 of Set 1 | qaqortoq
# Processing Record 44 of Set 1 | papatowai
# Processing Record 45 of Set 1 | sainte catherine de la jacques cartier
# Processing Record 46 of Set 1 | port mathurin
# Processing Record 47 of Set 1 | broken hill
# Processing Record 48 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 49 of Set 1 | shimoda
# Processing Record 50 of Set 1 | ribeira grande
# Processing Record 0 of Set 2 | wailua homesteads
# Processing Record 1 of Set 2 | bochum
# Processing Record 2 of Set 2 | solnechnyy
# Processing Record 3 of Set 2 | newman
# Processing Record 4 of Set 2 | kudahuvadhoo
# Processing Record 5 of Set 2 | atafu village
# Processing Record 6 of Set 2 | fort mcmurray
# Processing Record 7 of Set 2 | adamstown
# Processing Record 8 of Set 2 | yellowknife
# Processing Record 9 of Set 2 | talnakh
# Processing Record 10 of Set 2 | vilyuchinsk
# Processing Record 11 of Set 2 | gadzhiyevo
# Processing Record 12 of Set 2 | kununurra
# Processing Record 13 of Set 2 | ulsteinvik
# Processing Record 14 of Set 2 | richards bay
# Processing Record 15 of Set 2 | kodinsk
# Processing Record 16 of Set 2 | kodiak
# Processing Record 17 of Set 2 | longyearbyen
# Processing Record 18 of Set 2 | fale old settlement
# Processing Record 19 of Set 2 | usinsk
# Processing Record 20 of Set 2 | tiksi
# Processing Record 21 of Set 2 | rio verde de mato grosso
# Processing Record 22 of Set 2 | bilibino
# Processing Record 23 of Set 2 | east london
# Processing Record 24 of Set 2 | parola
# Processing Record 25 of Set 2 | selfoss
# Processing Record 26 of Set 2 | hamilton
# Processing Record 27 of Set 2 | tamandare
# Processing Record 28 of Set 2 | bhimunipatnam
# Processing Record 29 of Set 2 | bardai
# Processing Record 30 of Set 2 | christchurch
# Processing Record 31 of Set 2 | fort st. john
# Processing Record 32 of Set 2 | anori
# Processing Record 33 of Set 2 | weligama
# Processing Record 34 of Set 2 | shortandy
# Processing Record 35 of Set 2 | kidal
# Processing Record 36 of Set 2 | sandnessjoen
# Processing Record 37 of Set 2 | haiku-pauwela
# Processing Record 38 of Set 2 | aasiaat
# Processing Record 39 of Set 2 | copala
# Processing Record 40 of Set 2 | keelung
# Processing Record 41 of Set 2 | westport
# Processing Record 42 of Set 2 | vila do maio
# Processing Record 43 of Set 2 | nar'yan-mar
# Processing Record 44 of Set 2 | ust-nera
# Processing Record 45 of Set 2 | revelstoke
# Processing Record 46 of Set 2 | hermanus
# Processing Record 47 of Set 2 | bonthe
# Processing Record 48 of Set 2 | buabidi
# City not found. Skipping...
# Processing Record 49 of Set 2 | pekan
# Processing Record 0 of Set 3 | invercargill
# Processing Record 1 of Set 3 | college
# Processing Record 2 of Set 3 | oriximina
# Processing Record 3 of Set 3 | yichun
# Processing Record 4 of Set 3 | weno
# Processing Record 5 of Set 3 | anadyr
# Processing Record 6 of Set 3 | khanty-mansiysk
# Processing Record 7 of Set 3 | carnarvon
# Processing Record 8 of Set 3 | igarka
# Processing Record 9 of Set 3 | sanctuary point
# Processing Record 10 of Set 3 | caconda
# Processing Record 11 of Set 3 | holualoa
# Processing Record 12 of Set 3 | cabo san lucas
# Processing Record 13 of Set 3 | rabo de peixe
# Processing Record 14 of Set 3 | camocim
# Processing Record 15 of Set 3 | puerto ayora
# Processing Record 16 of Set 3 | thompson
# Processing Record 17 of Set 3 | moires
# Processing Record 18 of Set 3 | port elizabeth
# Processing Record 19 of Set 3 | lompoc
# Processing Record 20 of Set 3 | el porvenir
# Processing Record 21 of Set 3 | argo
# Processing Record 22 of Set 3 | barentu
# Processing Record 23 of Set 3 | saint-francois
# Processing Record 24 of Set 3 | howrah
# Processing Record 25 of Set 3 | port lincoln
# Processing Record 26 of Set 3 | port alfred
# Processing Record 27 of Set 3 | mirpur sakro
# Processing Record 28 of Set 3 | tranovaho
# City not found. Skipping...
# Processing Record 29 of Set 3 | laguna
# Processing Record 30 of Set 3 | port saint john's
# Processing Record 31 of Set 3 | champerico
# Processing Record 32 of Set 3 | shelbyville
# Processing Record 33 of Set 3 | el bauga
# Processing Record 34 of Set 3 | isla mujeres
# Processing Record 35 of Set 3 | saluzzo
# Processing Record 36 of Set 3 | teknaf
# Processing Record 37 of Set 3 | nelson bay
# Processing Record 38 of Set 3 | pacific grove
# Processing Record 39 of Set 3 | georgetown
# Processing Record 40 of Set 3 | de witt
# Processing Record 41 of Set 3 | jamestown
# Processing Record 42 of Set 3 | vadso
# Processing Record 43 of Set 3 | pauri
# Processing Record 44 of Set 3 | businga
# Processing Record 45 of Set 3 | thunder bay
# Processing Record 46 of Set 3 | aroma
# Processing Record 47 of Set 3 | nyagan
# Processing Record 48 of Set 3 | hawaiian paradise park
# Processing Record 49 of Set 3 | varna
# Processing Record 0 of Set 4 | gunupur
# Processing Record 1 of Set 4 | klyuchi
# Processing Record 2 of Set 4 | portland
# Processing Record 3 of Set 4 | san jose del cabo
# Processing Record 4 of Set 4 | trincomalee
# Processing Record 5 of Set 4 | nurabad
# Processing Record 6 of Set 4 | tauranga
# Processing Record 7 of Set 4 | lihue
# Processing Record 8 of Set 4 | margate
# Processing Record 9 of Set 4 | tangalle
# Processing Record 10 of Set 4 | avarua
# Processing Record 11 of Set 4 | berezovskiy
# Processing Record 12 of Set 4 | luanda
# Processing Record 13 of Set 4 | bredasdorp
# Processing Record 14 of Set 4 | kirensk
# Processing Record 15 of Set 4 | norilsk
# Processing Record 16 of Set 4 | smidovich
# Processing Record 17 of Set 4 | punta arenas
# Processing Record 18 of Set 4 | kolonia
# Processing Record 19 of Set 4 | urucui
# Processing Record 20 of Set 4 | sao felix do xingu
# Processing Record 21 of Set 4 | berezovo
# Processing Record 22 of Set 4 | dudley park
# Processing Record 23 of Set 4 | selma
# Processing Record 24 of Set 4 | touros
# Processing Record 25 of Set 4 | serenje
# Processing Record 26 of Set 4 | iquique
# Processing Record 27 of Set 4 | bayji
# Processing Record 28 of Set 4 | tura
# Processing Record 29 of Set 4 | praia da vitoria
# Processing Record 30 of Set 4 | constantia
# Processing Record 31 of Set 4 | quang ngai
# Processing Record 32 of Set 4 | zarzis
# Processing Record 33 of Set 4 | okhotsk
# Processing Record 34 of Set 4 | sur
# Processing Record 35 of Set 4 | deridder
# Processing Record 36 of Set 4 | ouellah
# City not found. Skipping...
# Processing Record 37 of Set 4 | trairi
# Processing Record 38 of Set 4 | huarmey
# Processing Record 39 of Set 4 | uturoa
# Processing Record 40 of Set 4 | antofagasta
# Processing Record 41 of Set 4 | san juan
# Processing Record 42 of Set 4 | begoro
# Processing Record 43 of Set 4 | kapuskasing
# Processing Record 44 of Set 4 | nemuro
# Processing Record 45 of Set 4 | palang
# Processing Record 46 of Set 4 | mukah
# City not found. Skipping...
# Processing Record 47 of Set 4 | inskoy
# Processing Record 48 of Set 4 | sitka
# Processing Record 49 of Set 4 | tarnogskiy gorodok
# Processing Record 0 of Set 5 | tolmezzo
# Processing Record 1 of Set 5 | williamson
# Processing Record 2 of Set 5 | pudozh
# Processing Record 3 of Set 5 | saint-joseph
# Processing Record 4 of Set 5 | sola
# Processing Record 5 of Set 5 | popondetta
# Processing Record 6 of Set 5 | jinchang
# Processing Record 7 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 8 of Set 5 | boston
# Processing Record 9 of Set 5 | dudinka
# Processing Record 10 of Set 5 | kharp
# Processing Record 11 of Set 5 | kenora
# Processing Record 12 of Set 5 | ratnagiri
# Processing Record 13 of Set 5 | chonchi
# Processing Record 14 of Set 5 | enewetak
# Processing Record 15 of Set 5 | xinmin
# Processing Record 16 of Set 5 | hadibu
# Processing Record 17 of Set 5 | st. john's
# Processing Record 18 of Set 5 | liuduzhai
# Processing Record 19 of Set 5 | shahr-e kord
# Processing Record 20 of Set 5 | kalifornsky
# Processing Record 21 of Set 5 | bowen
# Processing Record 22 of Set 5 | pandan
# Processing Record 23 of Set 5 | midoun
# Processing Record 24 of Set 5 | alofi
# Processing Record 25 of Set 5 | itaituba
# Processing Record 26 of Set 5 | kourou
# Processing Record 27 of Set 5 | dryden
# Processing Record 28 of Set 5 | afaahiti
# Processing Record 29 of Set 5 | nurota
# Processing Record 30 of Set 5 | mount horeb
# Processing Record 31 of Set 5 | maile
# Processing Record 32 of Set 5 | juneau
# Processing Record 33 of Set 5 | perry
# Processing Record 34 of Set 5 | jaca
# Processing Record 35 of Set 5 | pizarro
# Processing Record 36 of Set 5 | jacobina
# Processing Record 37 of Set 5 | banda aceh
# Processing Record 38 of Set 5 | masons bay
# City not found. Skipping...
# Processing Record 39 of Set 5 | la passe
# Processing Record 40 of Set 5 | greymouth
# Processing Record 41 of Set 5 | whitehorse
# Processing Record 42 of Set 5 | nuuk
# Processing Record 43 of Set 5 | badger
# Processing Record 44 of Set 5 | upper dir
# Processing Record 45 of Set 5 | miranda
# Processing Record 46 of Set 5 | bamboo flat
# Processing Record 47 of Set 5 | kingston
# Processing Record 48 of Set 5 | san jose village
# City not found. Skipping...
# Processing Record 49 of Set 5 | alice springs
# Processing Record 0 of Set 6 | tolanaro
# Processing Record 1 of Set 6 | lae
# Processing Record 2 of Set 6 | altea
# Processing Record 3 of Set 6 | crane
# Processing Record 4 of Set 6 | hoxtolgay
# City not found. Skipping...
# Processing Record 5 of Set 6 | at-bashi
# Processing Record 6 of Set 6 | ad dawadimi
# Processing Record 7 of Set 6 | sylt-ost
# Processing Record 8 of Set 6 | hithadhoo
# Processing Record 9 of Set 6 | sinabang
# Processing Record 10 of Set 6 | lewiston orchards
# Processing Record 11 of Set 6 | ambovombe
# Processing Record 12 of Set 6 | yeed
# Processing Record 13 of Set 6 | leava
# Processing Record 14 of Set 6 | san jose
# Processing Record 15 of Set 6 | kamina
# Processing Record 16 of Set 6 | obo
# Processing Record 17 of Set 6 | san patricio
# Processing Record 18 of Set 6 | sierpc
# Processing Record 19 of Set 6 | la ronge
# Processing Record 20 of Set 6 | gracemere
# Processing Record 21 of Set 6 | carahue
# Processing Record 22 of Set 6 | howard springs
# Processing Record 23 of Set 6 | mahdia
# Processing Record 24 of Set 6 | sudogda
# Processing Record 25 of Set 6 | mariental
# Processing Record 26 of Set 6 | sao vicente
# Processing Record 27 of Set 6 | seaside
# Processing Record 28 of Set 6 | malango
# Processing Record 29 of Set 6 | safaga
# Processing Record 30 of Set 6 | baturaja
# Processing Record 31 of Set 6 | tamasi
# Processing Record 32 of Set 6 | cargados carajos
# City not found. Skipping...
# Processing Record 33 of Set 6 | minas de marcona
# Processing Record 34 of Set 6 | sredets
# Processing Record 35 of Set 6 | vilyuysk
# Processing Record 36 of Set 6 | udachny
# Processing Record 37 of Set 6 | whakatane
# Processing Record 38 of Set 6 | dharchula
# Processing Record 39 of Set 6 | sabac
# Processing Record 40 of Set 6 | brownfield
# Processing Record 41 of Set 6 | yayva
# Processing Record 42 of Set 6 | cole harbour
# Processing Record 43 of Set 6 | swellendam
# Processing Record 44 of Set 6 | kayangel
# Processing Record 45 of Set 6 | puerto colombia
# Processing Record 46 of Set 6 | luau
# Processing Record 47 of Set 6 | barguzin
# Processing Record 48 of Set 6 | estevan
# Processing Record 49 of Set 6 | santa ana
# Processing Record 0 of Set 7 | prado
# Processing Record 1 of Set 7 | brookings
# Processing Record 2 of Set 7 | carrizal
# Processing Record 3 of Set 7 | new norfolk
# Processing Record 4 of Set 7 | santo antonio
# Processing Record 5 of Set 7 | ambon
# Processing Record 6 of Set 7 | saldanha
# Processing Record 7 of Set 7 | pukekohe east
# Processing Record 8 of Set 7 | sao gabriel da cachoeira
# Processing Record 9 of Set 7 | deschutes river woods
# Processing Record 10 of Set 7 | mount isa
# Processing Record 11 of Set 7 | manggar
# Processing Record 12 of Set 7 | driefontein
# Processing Record 13 of Set 7 | cockburn town
# Processing Record 14 of Set 7 | colonia menno
# Processing Record 15 of Set 7 | kone
# Processing Record 16 of Set 7 | awjilah
# Processing Record 17 of Set 7 | winchester center
# Processing Record 18 of Set 7 | oranjemund
# Processing Record 19 of Set 7 | utrik
# Processing Record 20 of Set 7 | chunskiy
# Processing Record 21 of Set 7 | egersund
# Processing Record 22 of Set 7 | vorkuta
# Processing Record 23 of Set 7 | egilsstadir
# Processing Record 24 of Set 7 | dalbandin
# Processing Record 25 of Set 7 | gunjur
# Processing Record 26 of Set 7 | ravar
# Processing Record 27 of Set 7 | kelibia
# Processing Record 28 of Set 7 | guanica
# Processing Record 29 of Set 7 | song cau
# Processing Record 30 of Set 7 | robore
# Processing Record 31 of Set 7 | pitanga
# Processing Record 32 of Set 7 | novodvinsk
# Processing Record 33 of Set 7 | namibe
# Processing Record 34 of Set 7 | keflavik
# Processing Record 35 of Set 7 | arraial do cabo
# Processing Record 36 of Set 7 | pariaman
# Processing Record 37 of Set 7 | labrador city
# Processing Record 38 of Set 7 | cururupu
# Processing Record 39 of Set 7 | tulnici
# Processing Record 40 of Set 7 | cutro
# Processing Record 41 of Set 7 | flying fish cove
# Processing Record 42 of Set 7 | shagonar
# Processing Record 43 of Set 7 | tirodi
# Processing Record 44 of Set 7 | dunedin
# Processing Record 45 of Set 7 | bol'sherech'ye
# Processing Record 46 of Set 7 | pisco
# Processing Record 47 of Set 7 | nsanje
# Processing Record 48 of Set 7 | malkapur
# Processing Record 49 of Set 7 | leua
# Processing Record 0 of Set 8 | illizi
# Processing Record 1 of Set 8 | saudarkrokur
# Processing Record 2 of Set 8 | turpan
# Processing Record 3 of Set 8 | cidreira
# Processing Record 4 of Set 8 | susuman
# Processing Record 5 of Set 8 | lata
# Processing Record 6 of Set 8 | itamaraca
# Processing Record 7 of Set 8 | vila franca do campo
# Processing Record 8 of Set 8 | parauapebas
# Processing Record 9 of Set 8 | ballito
# Processing Record 10 of Set 8 | tidjikja
# Processing Record 11 of Set 8 | vorgashor
# Processing Record 12 of Set 8 | negapatam
# Processing Record 13 of Set 8 | naze
# Processing Record 14 of Set 8 | inarajan village
# Processing Record 15 of Set 8 | peterhead
# Processing Record 16 of Set 8 | kampene
# Processing Record 17 of Set 8 | vodnyy
# Processing Record 18 of Set 8 | santana
# Processing Record 19 of Set 8 | camarinas
# Processing Record 20 of Set 8 | coyhaique
# Processing Record 21 of Set 8 | omdurman
# Processing Record 22 of Set 8 | fonte boa
# Processing Record 23 of Set 8 | hirara
# Processing Record 24 of Set 8 | inekar
# City not found. Skipping...
# Processing Record 25 of Set 8 | palma del rio
# Processing Record 26 of Set 8 | proletar
# Processing Record 27 of Set 8 | mejit
# Processing Record 28 of Set 8 | tindouf
# Processing Record 29 of Set 8 | sarakhs
# Processing Record 30 of Set 8 | kosong
# Processing Record 31 of Set 8 | zapala
# Processing Record 32 of Set 8 | mumford
# Processing Record 33 of Set 8 | swift current
# Processing Record 34 of Set 8 | pont rouge
# Processing Record 35 of Set 8 | acajutla
# Processing Record 36 of Set 8 | iskateley
# Processing Record 37 of Set 8 | bracebridge
# Processing Record 38 of Set 8 | nago
# Processing Record 39 of Set 8 | ola
# Processing Record 40 of Set 8 | khandyga
# Processing Record 41 of Set 8 | marsabit
# Processing Record 42 of Set 8 | puerto baquerizo moreno
# Processing Record 43 of Set 8 | baie-saint-paul
# Processing Record 44 of Set 8 | avenal
# Processing Record 45 of Set 8 | ta`u
# Processing Record 46 of Set 8 | duong dong
# Processing Record 47 of Set 8 | priargunsk
# Processing Record 48 of Set 8 | mao
# Processing Record 49 of Set 8 | letlhakeng
# Processing Record 0 of Set 9 | amargosa
# Processing Record 1 of Set 9 | el bolson
# Processing Record 2 of Set 9 | elmendorf air force base
# City not found. Skipping...
# Processing Record 3 of Set 9 | salalah
# Processing Record 4 of Set 9 | al jawf
# Processing Record 5 of Set 9 | devinuwara
# City not found. Skipping...
# Processing Record 6 of Set 9 | aioun
# Processing Record 7 of Set 9 | kiknur
# Processing Record 8 of Set 9 | san luis de la loma
# Processing Record 9 of Set 9 | conception bay south
# Processing Record 10 of Set 9 | mancio lima
# Processing Record 11 of Set 9 | sofifi
# City not found. Skipping...
# Processing Record 12 of Set 9 | mar del plata
# Processing Record 13 of Set 9 | jayapura
# Processing Record 14 of Set 9 | langepas
# Processing Record 15 of Set 9 | freetown
# Processing Record 16 of Set 9 | kuanda
# Processing Record 17 of Set 9 | villamontes
# Processing Record 18 of Set 9 | atyrau
# Processing Record 19 of Set 9 | mesoraca
# Processing Record 20 of Set 9 | calvinia
# Processing Record 21 of Set 9 | mhamid
# Processing Record 22 of Set 9 | mccook
# Processing Record 23 of Set 9 | pryamitsyno
# Processing Record 24 of Set 9 | sao martinho
# Processing Record 25 of Set 9 | kupang
# Processing Record 26 of Set 9 | machakos
# Processing Record 27 of Set 9 | dakhla
# Processing Record 28 of Set 9 | suva
# Processing Record 29 of Set 9 | nkove
# Processing Record 30 of Set 9 | hagere selam
# Processing Record 31 of Set 9 | bengkulu
# Processing Record 32 of Set 9 | akureyri
# Processing Record 33 of Set 9 | antsiranana
# Processing Record 34 of Set 9 | gbarnga
# Processing Record 35 of Set 9 | papar
# Processing Record 36 of Set 9 | kargil
# Processing Record 37 of Set 9 | bel ombre
# Processing Record 38 of Set 9 | ciudad guadalupe victoria
# Processing Record 39 of Set 9 | inhambane
# Processing Record 40 of Set 9 | santiago de cao
# Processing Record 41 of Set 9 | asbury
# Processing Record 42 of Set 9 | jiamusi
# Processing Record 43 of Set 9 | vernon
# Processing Record 44 of Set 9 | rosario
# Processing Record 45 of Set 9 | ust-tsilma
# Processing Record 46 of Set 9 | jiuquan
# Processing Record 47 of Set 9 | whyalla stuart
# City not found. Skipping...
# Processing Record 48 of Set 9 | mount pearl
# Processing Record 49 of Set 9 | buncrana
# Processing Record 0 of Set 10 | corumba
# Processing Record 1 of Set 10 | luderitz
# Processing Record 2 of Set 10 | mahibadhoo
# Processing Record 3 of Set 10 | kailua-kona
# Processing Record 4 of Set 10 | muynoq
# Processing Record 5 of Set 10 | polyarnyy
# Processing Record 6 of Set 10 | tralee
# Processing Record 7 of Set 10 | carmelo
# Processing Record 8 of Set 10 | phongsali
# Processing Record 9 of Set 10 | zahedan
# Processing Record 10 of Set 10 | dingzhou
# Processing Record 11 of Set 10 | chiili
# City not found. Skipping...
# Processing Record 12 of Set 10 | forde
# Processing Record 13 of Set 10 | bharatpur
# Processing Record 14 of Set 10 | balabac
# Processing Record 15 of Set 10 | uitenhage
# Processing Record 16 of Set 10 | novyy urengoy
# Processing Record 17 of Set 10 | surovikino
# Processing Record 18 of Set 10 | takamaka
# City not found. Skipping...
# Processing Record 19 of Set 10 | tofol
# Processing Record 20 of Set 10 | yanbu
# Processing Record 21 of Set 10 | noumea
# Processing Record 22 of Set 10 | yeppoon
# Processing Record 23 of Set 10 | zyryanovsk
# Processing Record 24 of Set 10 | broome
# Processing Record 25 of Set 10 | ujae
# Processing Record 26 of Set 10 | kattivakkam
# Processing Record 27 of Set 10 | escanaba
# Processing Record 28 of Set 10 | chalus
# Processing Record 29 of Set 10 | port augusta
# Processing Record 30 of Set 10 | panaba
# Processing Record 31 of Set 10 | cooma
# Processing Record 32 of Set 10 | roma
# Processing Record 33 of Set 10 | kolpashevo
# Processing Record 34 of Set 10 | alo
# Processing Record 35 of Set 10 | grand-lahou
# Processing Record 36 of Set 10 | yuzhno-kurilsk
# Processing Record 37 of Set 10 | ponta delgada
# Processing Record 38 of Set 10 | sovetskiy
# Processing Record 39 of Set 10 | saint-just-en-chaussee
# Processing Record 40 of Set 10 | kutahya
# Processing Record 41 of Set 10 | nagqu
# Processing Record 42 of Set 10 | mawu
# Processing Record 43 of Set 10 | tomar
# Processing Record 44 of Set 10 | sao paulo de olivenca
# Processing Record 45 of Set 10 | berdigestyakh
# Processing Record 46 of Set 10 | el haouaria
# Processing Record 47 of Set 10 | myitkyina
# Processing Record 48 of Set 10 | kapa'a
# Processing Record 49 of Set 10 | forster
# Processing Record 0 of Set 11 | horta
# Processing Record 1 of Set 11 | baharly
# Processing Record 2 of Set 11 | inyati
# Processing Record 3 of Set 11 | vingt cinq
# City not found. Skipping...
# Processing Record 4 of Set 11 | leh
# Processing Record 5 of Set 11 | opuwo
# Processing Record 6 of Set 11 | gamla uppsala
# Processing Record 7 of Set 11 | kotabumi
# Processing Record 8 of Set 11 | lerwick
# Processing Record 9 of Set 11 | madaoua
# Processing Record 10 of Set 11 | sikonge
# Processing Record 11 of Set 11 | al jadid
# Processing Record 12 of Set 11 | tvoroyri
# Processing Record 13 of Set 11 | ondjiva
# Processing Record 14 of Set 11 | arroyo
# Processing Record 15 of Set 11 | macae
# Processing Record 16 of Set 11 | kotra
# Processing Record 17 of Set 11 | yantarnyy
# Processing Record 18 of Set 11 | quinte west
# Processing Record 19 of Set 11 | wladyslawowo
# Processing Record 20 of Set 11 | diapaga
# Processing Record 21 of Set 11 | gulf shores
# Processing Record 22 of Set 11 | antonio enes
# Processing Record 23 of Set 11 | mogadishu
# Processing Record 24 of Set 11 | libertad
# Processing Record 25 of Set 11 | kalix
# Processing Record 26 of Set 11 | nukunonu
# City not found. Skipping...
# Processing Record 27 of Set 11 | mpulungu
# Processing Record 28 of Set 11 | chirkey
# Processing Record 29 of Set 11 | galliano
# Processing Record 30 of Set 11 | motygino
# Processing Record 31 of Set 11 | sonsorol village
# City not found. Skipping...
# Processing Record 32 of Set 11 | colonia
# Processing Record 33 of Set 11 | island harbour
# Processing Record 34 of Set 11 | dwarka
# Processing Record 35 of Set 11 | bei'an
# Processing Record 36 of Set 11 | karukh
# Processing Record 37 of Set 11 | kerikeri
# Processing Record 38 of Set 11 | amungan
# Processing Record 39 of Set 11 | bubaque
# Processing Record 40 of Set 11 | sao joao da barra
# Processing Record 41 of Set 11 | auterive
# Processing Record 42 of Set 11 | sherbakul'
# Processing Record 43 of Set 11 | las lomitas
# Processing Record 44 of Set 11 | zaragoza
# Processing Record 45 of Set 11 | vyazemskiy
# Processing Record 46 of Set 11 | bedele
# Processing Record 47 of Set 11 | east tamworth
# Processing Record 48 of Set 11 | al khafji
# Processing Record 49 of Set 11 | ghat
# Processing Record 0 of Set 12 | uglegorsk
# Processing Record 1 of Set 12 | el calafate
# Processing Record 2 of Set 12 | saint-philippe
# Processing Record 3 of Set 12 | zhangatas
# Processing Record 4 of Set 12 | san juan de miraflores
# Processing Record 5 of Set 12 | juan rodriguez clara
# Processing Record 6 of Set 12 | magugu
# Processing Record 7 of Set 12 | le vauclin
# Processing Record 8 of Set 12 | beyneu
# Processing Record 9 of Set 12 | vetovo
# Processing Record 10 of Set 12 | gdov
# Processing Record 11 of Set 12 | manakara
# Processing Record 12 of Set 12 | menderes
# Processing Record 13 of Set 12 | zarate
# Processing Record 14 of Set 12 | luwuk
# Processing Record 15 of Set 12 | chateaudun
# Processing Record 16 of Set 12 | hotan
# Processing Record 17 of Set 12 | barakani
# Processing Record 18 of Set 12 | coquimbo
# Processing Record 19 of Set 12 | tikamgarh
# Processing Record 20 of Set 12 | kaspiyskiy
# Processing Record 21 of Set 12 | masindi
# Processing Record 22 of Set 12 | parvatsar
# Processing Record 23 of Set 12 | nacozari viejo
# Processing Record 24 of Set 12 | tabou
# Processing Record 25 of Set 12 | putian
# Processing Record 26 of Set 12 | osorno
# Processing Record 27 of Set 12 | porto novo
# Processing Record 28 of Set 12 | boa vista
# Processing Record 29 of Set 12 | bantay
# Processing Record 30 of Set 12 | matiguas
# Processing Record 31 of Set 12 | pangoa
# Processing Record 32 of Set 12 | malanje
# Processing Record 33 of Set 12 | port loko
# Processing Record 34 of Set 12 | magadan
# Processing Record 35 of Set 12 | la'ie
# Processing Record 36 of Set 12 | geraldton
# Processing Record 37 of Set 12 | nuku'alofa
# Processing Record 38 of Set 12 | dong ha
# Processing Record 39 of Set 12 | sharur city
# City not found. Skipping...
# Processing Record 40 of Set 12 | minas de matahambre
# City not found. Skipping...
# Processing Record 41 of Set 12 | mzuzu
# Processing Record 42 of Set 12 | lorengau
# Processing Record 43 of Set 12 | kinablangan
# Processing Record 44 of Set 12 | chukhloma
# Processing Record 45 of Set 12 | changleng
# Processing Record 46 of Set 12 | maintirano
# Processing Record 47 of Set 12 | papao
# Processing Record 48 of Set 12 | ha'il
# Processing Record 49 of Set 12 | mil'kovo
# Processing Record 0 of Set 13 | villacidro
# Processing Record 1 of Set 13 | lincheng
# Processing Record 2 of Set 13 | bairnsdale
# Processing Record 3 of Set 13 | gadani
# Processing Record 4 of Set 13 | newberry
# Processing Record 5 of Set 13 | muli
# Processing Record 6 of Set 13 | vorozhba
# Processing Record 7 of Set 13 | mandalgovi
# Processing Record 8 of Set 13 | aykhal
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          585
# Lat           585
# Lng           585
# Max Temp      585
# Humidity      585
# Cloudiness    585
# Wind Speed    585
# Country       585
# Date          585
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        tongliao  43.6125  122.2653     59.22        23          69
# 1       ilulissat  69.2167  -51.1000     26.62        50          30
# 2  margaret river -33.9500  115.0667     60.53        64          99
# 3     kingsbridge  50.2845   -3.7764     56.61        89         100
# 4  puerto natales -51.7236  -72.4875     39.25        92          97
#
#    Wind Speed Country                 Date
# 0       21.07      CN  2023-10-04 03:48:01
# 1       11.50      GL  2023-10-04 03:48:01
# 2        7.11      AU  2023-10-04 03:48:01
# 3       10.71      GB  2023-10-04 03:48:02
# 4        6.87      CL  2023-10-04 03:43:31

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              tongliao  43.6125  122.2653     59.22        23          69
# 1             ilulissat  69.2167  -51.1000     26.62        50          30
# 2        margaret river -33.9500  115.0667     60.53        64          99
# 3           kingsbridge  50.2845   -3.7764     56.61        89         100
# 4        puerto natales -51.7236  -72.4875     39.25        92          97
#
#          Wind Speed Country                 Date
# City_ID
# 0             21.07      CN  2023-10-04 03:48:01
# 1             11.50      GL  2023-10-04 03:48:01
# 2              7.11      AU  2023-10-04 03:48:01
# 3             10.71      GB  2023-10-04 03:48:02
# 4              6.87      CL  2023-10-04 03:43:31

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
lat = city_data_df["Lat"]
max_temp = city_data_df["Max Temp"]
plt.scatter(lat, max_temp)


# Incorporate the other graph properties
plt.grid(True)
plt.ylabel("Tempature (F)")
plt.xlabel("Latitude")
plt.title("Latitude vs Temperature")
           
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
lat = city_data_df["Lat"]
Humidity = city_data_df["Humidity"]
plt.scatter(lat, Humidity)


# Incorporate the other graph properties
plt.grid(True)
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.title("Latitude vs Humidity")
# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
lat = city_data_df["Lat"]
Cloudiness = city_data_df["Cloudiness"]
plt.scatter(lat, Humidity)


# Incorporate the other graph properties
plt.grid(True)
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.title("Latitude vs Cloudiness")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
lat = city_data_df["Lat"]
wind = city_data_df["Wind Speed"]
plt.scatter(lat, wind)


# Incorporate the other graph properties
plt.grid(True)
plt.ylabel("Wind Spped (m/s)")
plt.xlabel("Latitude")
plt.title("Latitude vs Wind Speed")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regression_plot(x_values, y_values):

    #Run linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    # Plot scatter plot
    plt.scatter(x_values,y_values)
    
    # Plot regression line
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,(10,10),fontsize=15,color="red")
    
    # Label plot
    plt.xlabel('Latitude')
    plt.ylabel('y_values')
    
    # Print r square value
    print(f"The r-value is: {rvalue**2}")
    
# Show plot
plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
north_df = city_data_df.loc[city_data_df['Lat']>= 0]

# Display sample data
north_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           tongliao  43.6125  122.2653     59.22        23          69
# 1          ilulissat  69.2167  -51.1000     26.62        50          30
# 3        kingsbridge  50.2845   -3.7764     56.61        89         100
# 5        kongsvinger  60.1905   11.9977     47.07        87          14
# 6             saipan  15.1355  145.7010     88.50        70          40
#
#          Wind Speed Country                 Date
# City_ID
# 0             21.07      CN  2023-10-04 03:48:01
# 1             11.50      GL  2023-10-04 03:48:01
# 3             10.71      GB  2023-10-04 03:48:02
# 5              4.14      NO  2023-10-04 03:48:02
# 6             13.80      MP  2023-10-04 03:48:02

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
south_df = city_data_df.loc[city_data_df['Lat'] < 0]

# Display sample data
south_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2        margaret river -33.9500  115.0667     60.53        64          99
# 4        puerto natales -51.7236  -72.4875     39.25        92          97
# 7           west island -12.1568   96.8225     80.58        65          40
# 9              waitangi -43.9535 -176.5597     48.81        78          14
# 10            ulladulla -35.3500  150.4667     74.77        53         100
#
#          Wind Speed Country                 Date
# City_ID
# 2              7.11      AU  2023-10-04 03:48:01
# 4              6.87      CL  2023-10-04 03:43:31
# 7             19.57      CC  2023-10-04 03:48:02
# 9              5.01      NZ  2023-10-04 03:48:02
# 10            17.52      AU  2023-10-04 03:48:02

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = north_df['Lat']
y_values = north_df['Max Temp']

north_stats = linear_regression_plot(x_values, y_values)
north_stats
# Out:
# The r-value is: 0.7381902903308158

# %%
# Linear regression on Southern Hemisphere
x_values = south_df['Lat']
y_values = south_df['Max Temp']

south_stats = linear_regression_plot(x_values, y_values)
south_stats
# Out:
# The r-value is: 0.529556481877339

# %% [markdown]
# **Discussion about the linear relationship:**
# - countries closer to the equator tend to have a warmer max temp
# - the further you move from the equator, whether it is north or south, the max tempature drops

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = north_df['Lat']
y_values = north_df['Humidity']

north_stats = linear_regression_plot(x_values, y_values)
north_stats
# Out:
# The r-value is: 0.004388821626677896

# %%
# Southern Hemisphere
x_values = south_df['Lat']
y_values = south_df['Humidity']

south_stats = linear_regression_plot(x_values, y_values)
south_stats
# Out:
# The r-value is: 0.015854572275569506

# %% [markdown]
# **Discussion about the linear relationship:** - The lines of both graphs have similar slops\n",
#    - The slopes are postive and increase
#    - It is interesting that the further north you go, the
#    humditiy increasing. it is not linked to the equator

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = north_df['Lat']
y_values = north_df['Cloudiness']

north_stats = linear_regression_plot(x_values, y_values)
north_stats
# Out:
# The r-value is: 0.016594170637229663

# %%
# Southern Hemisphere
x_values = south_df['Lat']
y_values = south_df['Cloudiness']

south_stats = linear_regression_plot(x_values, y_values)
south_stats
# Out:
# The r-value is: 0.0006155712648645685

# %% [markdown]
# **Discussion about the linear relationship:**
# - The lines are almost identical.
# - The line does not follow the path of the points at
# - Cloudness appears to be common in places, no matter if you are close to the equator vs north/south

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = north_df['Lat']
y_values = north_df['Wind Speed']

north_stats = linear_regression_plot(x_values, y_values)
north_stats
# Out:
# The r-value is: 0.02766469280503347

# %%
# Southern Hemisphere
x_values = south_df['Lat']
y_values = south_df['Wind Speed']

south_stats = linear_regression_plot(x_values, y_values)
south_stats
# Out:
# The r-value is: 0.016842188704760088

# %% [markdown]
# **Discussion about the linear relationship:**
#  - The wind speed is higher the further away you are from the equator
#  - The trend for wind speed from the data set is between 15 - 5 mph
