# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import datetime

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

weather_api_key
# Out:
# '92b2ff9dbe4f85400c927eb43a04b513'

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 586

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=92b2ff9dbe4f85400c927eb43a04b513
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | palikir - national government center
# Processing Record 2 of Set 1 | lensk
# Processing Record 3 of Set 1 | dunedin
# Processing Record 4 of Set 1 | limassol
# Processing Record 5 of Set 1 | richards bay
# Processing Record 6 of Set 1 | yeed
# Processing Record 7 of Set 1 | adamstown
# Processing Record 8 of Set 1 | margaret river
# Processing Record 9 of Set 1 | udachny
# Processing Record 10 of Set 1 | lihue
# Processing Record 11 of Set 1 | waitangi
# Processing Record 12 of Set 1 | 'ohonua
# City not found. Skipping...
# Processing Record 13 of Set 1 | port-aux-francais
# Processing Record 14 of Set 1 | westport
# Processing Record 15 of Set 1 | canitas de felipe pescador
# Processing Record 16 of Set 1 | delafield
# Processing Record 17 of Set 1 | galliano
# Processing Record 18 of Set 1 | utrik
# Processing Record 19 of Set 1 | blackmans bay
# Processing Record 20 of Set 1 | east london
# Processing Record 21 of Set 1 | college
# Processing Record 22 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 23 of Set 1 | rudnyy
# Processing Record 24 of Set 1 | klyuchi
# Processing Record 25 of Set 1 | bethel
# Processing Record 26 of Set 1 | yellowknife
# Processing Record 27 of Set 1 | howrah
# Processing Record 28 of Set 1 | ilulissat
# Processing Record 29 of Set 1 | polyany
# Processing Record 30 of Set 1 | lake city
# Processing Record 31 of Set 1 | zangguy
# City not found. Skipping...
# Processing Record 32 of Set 1 | nouadhibou
# Processing Record 33 of Set 1 | grytviken
# Processing Record 34 of Set 1 | uba
# Processing Record 35 of Set 1 | upington
# Processing Record 36 of Set 1 | nantucket
# Processing Record 37 of Set 1 | rumbek
# Processing Record 38 of Set 1 | albany
# Processing Record 39 of Set 1 | constantia
# Processing Record 40 of Set 1 | oyem
# Processing Record 41 of Set 1 | laguna
# Processing Record 36 of Set 4 | wotho
# Processing Record 37 of Set 4 | acarau
# Processing Record 38 of Set 4 | la lira
# Processing Record 39 of Set 4 | zapolyarnyy
# Processing Record 40 of Set 4 | mudgee
# Processing Record 41 of Set 4 | grand falls-windsor
# Processing Record 42 of Set 4 | qaqortoq
# Processing Record 43 of Set 4 | kavieng
# Processing Record 44 of Set 4 | brooks
# Processing Record 45 of Set 4 | aasiaat
# Processing Record 46 of Set 4 | kapa'a
# Processing Record 47 of Set 4 | west island
# Processing Record 48 of Set 4 | nova sintra
# Processing Record 49 of Set 4 | kingsland
# Processing Record 0 of Set 5 | geraldton
# Processing Record 1 of Set 5 | simmern
# Processing Record 2 of Set 5 | hatillo
# Processing Record 3 of Set 5 | la foa
# Processing Record 4 of Set 5 | akureyri
# Processing Record 5 of Set 5 | balaipungut
# Processing Record 6 of Set 5 | iranshahr
# Processing Record 7 of Set 5 | touros
# Processing Record 8 of Set 5 | novyy urgal
# Processing Record 9 of Set 5 | magdagachi
# Processing Record 10 of Set 5 | coro
# Processing Record 11 of Set 5 | baoqing
# Processing Record 12 of Set 5 | enoch
# Processing Record 13 of Set 5 | blairgowrie
# Processing Record 14 of Set 5 | penrith
# Processing Record 15 of Set 5 | bangassou
# Processing Record 16 of Set 5 | la peca
# Processing Record 17 of Set 5 | zarah sharan
# Processing Record 18 of Set 5 | egilsstadir
# Processing Record 19 of Set 5 | kingston
# Processing Record 20 of Set 5 | wanning
# Processing Record 21 of Set 5 | cumana
# Processing Record 22 of Set 5 | roxas
# Processing Record 23 of Set 5 | vilyuysk
# Processing Record 24 of Set 5 | timmins
# Processing Record 25 of Set 5 | valparaiso
# Processing Record 26 of Set 5 | hotan
# Processing Record 27 of Set 5 | port elizabeth
# Processing Record 28 of Set 5 | carmo do rio verde
# Processing Record 29 of Set 5 | yamada
# Processing Record 30 of Set 5 | haiku-pauwela
# Processing Record 31 of Set 5 | cozumel
# Processing Record 32 of Set 5 | afaahiti
# Processing Record 33 of Set 5 | ta`u
# Processing Record 34 of Set 5 | gadzhiyevo
# Processing Record 35 of Set 5 | kenitra
# Processing Record 36 of Set 5 | zhumysker
# Processing Record 37 of Set 5 | darlowo
# Processing Record 38 of Set 5 | fale old settlement
# Processing Record 39 of Set 5 | yaval
# Processing Record 40 of Set 5 | weno
# Processing Record 41 of Set 5 | kruisfontein
# Processing Record 42 of Set 5 | mount pearl
# Processing Record 43 of Set 5 | usogorsk
# Processing Record 44 of Set 5 | freetown
# Processing Record 45 of Set 5 | al burayqah
# Processing Record 46 of Set 5 | vilyuchinsk
# Processing Record 47 of Set 5 | beloyarskiy
# Processing Record 48 of Set 5 | ivdel'
# Processing Record 49 of Set 5 | fort stockton
# Processing Record 0 of Set 6 | arno
# Processing Record 1 of Set 6 | olyokminsk
# Processing Record 2 of Set 6 | ulladulla
# Processing Record 3 of Set 6 | kununurra
# Processing Record 4 of Set 6 | aioun
# Processing Record 5 of Set 6 | ouddorp
# Processing Record 6 of Set 6 | san julian
# Processing Record 7 of Set 6 | katsuura
# Processing Record 8 of Set 6 | uturoa
# Processing Record 9 of Set 6 | gan
# Processing Record 10 of Set 6 | wangaratta
# Processing Record 11 of Set 6 | mahina
# Processing Record 12 of Set 6 | miranda
# Processing Record 13 of Set 6 | bilao
# Processing Record 14 of Set 6 | pichucalco
# Processing Record 15 of Set 6 | tucuma
# Processing Record 16 of Set 6 | el sauzal de rodriguez
# Processing Record 17 of Set 6 | conception bay south
# Processing Record 18 of Set 6 | nova vicosa
# Processing Record 19 of Set 6 | puerto penasco
# Processing Record 20 of Set 6 | port douglas
# Processing Record 21 of Set 6 | guajara mirim
# Processing Record 22 of Set 6 | khamis mushait
# Processing Record 23 of Set 6 | kaiapoi
# Processing Record 24 of Set 6 | maues
# Processing Record 25 of Set 6 | dudinka
# Processing Record 26 of Set 6 | grande prairie
# Processing Record 27 of Set 6 | tymovskoye
# Processing Record 28 of Set 6 | espargos
# City not found. Skipping...
# Processing Record 29 of Set 6 | sajir
# Processing Record 30 of Set 6 | santa terezinha
# Processing Record 31 of Set 6 | pauini
# Processing Record 32 of Set 6 | klaksvik
# Processing Record 33 of Set 6 | betio village
# Processing Record 34 of Set 6 | nuuk
# Processing Record 35 of Set 6 | felipe carrillo puerto
# Processing Record 36 of Set 6 | flying fish cove
# Processing Record 37 of Set 6 | keflavik
# Processing Record 38 of Set 6 | el hamma
# Processing Record 39 of Set 6 | sayansk
# Processing Record 40 of Set 6 | mata-utu
# Processing Record 41 of Set 6 | tadine
# Processing Record 42 of Set 6 | isna
# Processing Record 43 of Set 6 | markovo
# Processing Record 44 of Set 6 | baganga
# Processing Record 45 of Set 6 | dakhla
# Processing Record 46 of Set 6 | jeremoabo
# Processing Record 47 of Set 6 | gazli
# Processing Record 48 of Set 6 | praya
# Processing Record 49 of Set 6 | mar del plata
# Processing Record 0 of Set 7 | el charco
# Processing Record 1 of Set 7 | floro
# Processing Record 2 of Set 7 | taroa
# Processing Record 3 of Set 7 | okhotsk
# Processing Record 4 of Set 7 | rostovka
# Processing Record 5 of Set 7 | tachilek
# City not found. Skipping...
# Processing Record 6 of Set 7 | puerto santa
# Processing Record 7 of Set 7 | yeppoon
# Processing Record 8 of Set 7 | manakara
# Processing Record 9 of Set 7 | uzhur
# Processing Record 10 of Set 7 | izberbash
# Processing Record 11 of Set 7 | vila velha
# Processing Record 12 of Set 7 | ejido benito juarez
# City not found. Skipping...
# Processing Record 13 of Set 7 | tranovaho
# City not found. Skipping...
# Processing Record 14 of Set 7 | cockburn town
# Processing Record 15 of Set 7 | new norfolk
# Processing Record 16 of Set 7 | al lagowa
# Processing Record 17 of Set 7 | bonthe
# Processing Record 18 of Set 7 | cativa
# Processing Record 19 of Set 7 | kupang
# Processing Record 20 of Set 7 | am djarass
# City not found. Skipping...
# Processing Record 21 of Set 7 | benton
# Processing Record 22 of Set 7 | benguela
# Processing Record 23 of Set 7 | grassano
# Processing Record 24 of Set 7 | palafrugell
# Processing Record 25 of Set 7 | dabakala
# Processing Record 26 of Set 7 | camarillo
# Processing Record 27 of Set 7 | port saint john's
# Processing Record 28 of Set 7 | camocim
# Processing Record 29 of Set 7 | ochakiv
# Processing Record 30 of Set 7 | san pedro pochutla
# Processing Record 2 of Set 9 | rancho palos verdes
# Processing Record 3 of Set 9 | hopelchen
# Processing Record 4 of Set 9 | thinadhoo
# Processing Record 5 of Set 9 | ghat
# Processing Record 6 of Set 9 | konarka
# Processing Record 7 of Set 9 | zaragoza
# Processing Record 8 of Set 9 | rio preto da eva
# Processing Record 9 of Set 9 | champerico
# Processing Record 10 of Set 9 | boise
# Processing Record 11 of Set 9 | karratha
# Processing Record 12 of Set 9 | burang
# Processing Record 13 of Set 9 | lisakovsk
# Processing Record 14 of Set 9 | karakoyunlu
# Processing Record 15 of Set 9 | unai
# Processing Record 16 of Set 9 | arteche
# Processing Record 17 of Set 9 | upata
# Processing Record 18 of Set 9 | tangalle
# Processing Record 19 of Set 9 | san jose village
# City not found. Skipping...
# Processing Record 20 of Set 9 | sabang
# Processing Record 21 of Set 9 | vila franca do campo
# Processing Record 22 of Set 9 | ocean pointe
# City not found. Skipping...
# Processing Record 23 of Set 9 | bel ombre
# Processing Record 24 of Set 9 | caluula
# Processing Record 25 of Set 9 | taupo
# Processing Record 26 of Set 9 | olhao
# Processing Record 27 of Set 9 | alice springs
# Processing Record 28 of Set 9 | goias
# Processing Record 29 of Set 9 | dawson creek
# Processing Record 30 of Set 9 | naze
# Processing Record 31 of Set 9 | colesberg
# Processing Record 32 of Set 9 | anadyr
# Processing Record 33 of Set 9 | kosh-agach
# Processing Record 34 of Set 9 | stavern
# Processing Record 35 of Set 9 | santo antonio do ica
# Processing Record 36 of Set 9 | that phanom
# Processing Record 37 of Set 9 | porto novo
# Processing Record 38 of Set 9 | arraial do cabo
# Processing Record 39 of Set 9 | chibougamau
# Processing Record 40 of Set 9 | tughyl
# Processing Record 41 of Set 9 | kazanskoye
# Processing Record 42 of Set 9 | i-n-salah
# Processing Record 43 of Set 9 | nishinoomote
# Processing Record 44 of Set 9 | bijie
# Processing Record 45 of Set 9 | kampung sungai ara
# Processing Record 46 of Set 9 | shevchenko
# Processing Record 47 of Set 9 | nabire
# Processing Record 48 of Set 9 | anloga
# Processing Record 49 of Set 9 | koungheul
# Processing Record 0 of Set 10 | monte alegre
# Processing Record 1 of Set 10 | kulia village
# City not found. Skipping...
# Processing Record 2 of Set 10 | kalianget
# Processing Record 3 of Set 10 | ponta delgada
# Processing Record 4 of Set 10 | neiafu
# Processing Record 5 of Set 10 | mufumbwe
# Processing Record 6 of Set 10 | amasra
# Processing Record 7 of Set 10 | kemijarvi
# Processing Record 8 of Set 10 | kyain seikgyi township
# City not found. Skipping...
# Processing Record 9 of Set 10 | sovetskiy
# Processing Record 10 of Set 10 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 11 of Set 10 | turpan
# Processing Record 12 of Set 10 | sijunjung
# Processing Record 13 of Set 10 | al majaridah
# Processing Record 14 of Set 10 | lido di jesolo
# Processing Record 15 of Set 10 | kedainiai
# Processing Record 16 of Set 10 | vilhena
# Processing Record 17 of Set 10 | seaside
# Processing Record 18 of Set 10 | mana
# Processing Record 19 of Set 10 | majene
# Processing Record 20 of Set 10 | challapata
# Processing Record 21 of Set 10 | archidona
# Processing Record 22 of Set 10 | al jawf
# Processing Record 23 of Set 10 | davyd-haradok
# Processing Record 24 of Set 10 | salekhard
# Processing Record 25 of Set 10 | khamgaon
# Processing Record 26 of Set 10 | tanjung sepat
# Processing Record 27 of Set 10 | douentza
# Processing Record 28 of Set 10 | columbiana
# Processing Record 29 of Set 10 | nizhnesortymskiy
# Processing Record 30 of Set 10 | yanliang
# Processing Record 31 of Set 10 | vingt cinq
# City not found. Skipping...
# Processing Record 32 of Set 10 | courtenay
# Processing Record 33 of Set 10 | ak'ordat
# Processing Record 34 of Set 10 | mariehamn
# Processing Record 35 of Set 10 | langres
# Processing Record 36 of Set 10 | eyl
# Processing Record 37 of Set 10 | guiratinga
# Processing Record 38 of Set 10 | fort bragg
# Processing Record 39 of Set 10 | buta
# Processing Record 40 of Set 10 | selfoss
# Processing Record 41 of Set 10 | kotlas
# Processing Record 42 of Set 10 | port macquarie
# Processing Record 43 of Set 10 | aykhal
# Processing Record 44 of Set 10 | tank
# Processing Record 45 of Set 10 | vallenar
# Processing Record 46 of Set 10 | smara
# Processing Record 47 of Set 10 | lorengau
# Processing Record 48 of Set 10 | aginskoye
# Processing Record 49 of Set 10 | broken arrow
# Processing Record 0 of Set 11 | undurkhaan
# Processing Record 1 of Set 11 | milagros
# Processing Record 2 of Set 11 | bairnsdale
# Processing Record 3 of Set 11 | suva
# Processing Record 4 of Set 11 | plastun
# Processing Record 5 of Set 11 | gamba
# Processing Record 6 of Set 11 | dzhalagash
# Processing Record 7 of Set 11 | arraias
# Processing Record 8 of Set 11 | hasaki
# Processing Record 9 of Set 11 | kone
# Processing Record 10 of Set 11 | olinda
# Processing Record 11 of Set 11 | zhezqazghan
# Processing Record 12 of Set 11 | harstad
# Processing Record 13 of Set 11 | kayyerkan
# Processing Record 14 of Set 11 | bucerias
# Processing Record 15 of Set 11 | ilovlya
# Processing Record 16 of Set 11 | baidoa
# Processing Record 17 of Set 11 | kogalym
# Processing Record 18 of Set 11 | kukawa
# Processing Record 19 of Set 11 | houghton
# Processing Record 20 of Set 11 | carnarvon
# Processing Record 21 of Set 11 | rucar
# Processing Record 22 of Set 11 | san matias
# Processing Record 23 of Set 11 | indore
# Processing Record 24 of Set 11 | bikenibeu village
# Processing Record 25 of Set 11 | isangel
# Processing Record 26 of Set 11 | newnham
# Processing Record 27 of Set 11 | okondja
# Processing Record 28 of Set 11 | souillac
# Processing Record 29 of Set 11 | mo i rana
# Processing Record 30 of Set 11 | fuling
# Processing Record 31 of Set 11 | pucon
# Processing Record 32 of Set 11 | vigan
# Processing Record 33 of Set 11 | la sarre
# Processing Record 34 of Set 11 | kirando
# Processing Record 35 of Set 11 | kendari
# Processing Record 36 of Set 11 | kamyshin
# Processing Record 37 of Set 11 | yinchuan
# Processing Record 38 of Set 11 | khanbari
# Processing Record 39 of Set 11 | manay
# Processing Record 40 of Set 11 | n'zeto
# Processing Record 41 of Set 11 | maumere
# Processing Record 42 of Set 11 | tomatlan
# Processing Record 43 of Set 11 | lodja
# Processing Record 44 of Set 11 | ambovombe
# Processing Record 45 of Set 11 | andovoranto
# Processing Record 46 of Set 11 | ouellah
# City not found. Skipping...
# Processing Record 47 of Set 11 | millau
# Processing Record 48 of Set 11 | marsh harbour
# Processing Record 49 of Set 11 | ignalina
# Processing Record 0 of Set 12 | cidreira
# Processing Record 1 of Set 12 | ahau
# City not found. Skipping...
# Processing Record 2 of Set 12 | tsumeb
# Processing Record 3 of Set 12 | shkoder
# Processing Record 4 of Set 12 | esuk oron
# Processing Record 5 of Set 12 | chihuahua
# Processing Record 6 of Set 12 | mucurici
# Processing Record 7 of Set 12 | roosevelt
# Processing Record 8 of Set 12 | altamira
# Processing Record 9 of Set 12 | sao vicente
# Processing Record 10 of Set 12 | micheweni
# Processing Record 11 of Set 12 | lazaro cardenas
# Processing Record 12 of Set 12 | christchurch
# Processing Record 13 of Set 12 | santarem
# Processing Record 14 of Set 12 | volksrust
# Processing Record 15 of Set 12 | road town
# Processing Record 16 of Set 12 | lamu
# Processing Record 17 of Set 12 | anna regina
# Processing Record 18 of Set 12 | medicine hat
# Processing Record 19 of Set 12 | antofagasta
# Processing Record 20 of Set 12 | taos
# Processing Record 21 of Set 12 | alibag
# Processing Record 22 of Set 12 | maceio
# Processing Record 23 of Set 12 | opuwo
# Processing Record 24 of Set 12 | sungailiat
# Processing Record 25 of Set 12 | mukah
# City not found. Skipping...
# Processing Record 26 of Set 12 | colachel
# Processing Record 27 of Set 12 | machico
# Processing Record 28 of Set 12 | mogadishu
# Processing Record 29 of Set 12 | lloydminster
# Processing Record 30 of Set 12 | show low
# Processing Record 31 of Set 12 | onega
# Processing Record 32 of Set 12 | sinop
# Processing Record 33 of Set 12 | lapovo
# Processing Record 34 of Set 12 | grosse pointe farms
# Processing Record 35 of Set 12 | prado
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          559
# Lat           559
# Lng           559
# Max Temp      559
# Humidity      559
# Cloudiness    559
# Wind Speed    559
# Country       559
# Date          559
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                                    City      Lat       Lng  Max Temp  \
# 0  palikir - national government center   6.9248  158.1611     88.54
# 1                                 lensk  60.7253  114.9278     36.72
# 2                               dunedin -45.8742  170.5036     65.07
# 3                              limassol  34.6750   33.0333     68.07
# 4                          richards bay -28.7830   32.0377     70.48
#
#    Humidity  Cloudiness  Wind Speed Country                 Date
# 0        70          75        5.75      FM  2023-10-04 03:11:15
# 1        94         100        8.99      RU  2023-10-04 03:11:15
# 2        27         100        3.42      NZ  2023-10-04 03:09:54
# 3        64           0        3.44      CY  2023-10-04 03:11:16
# 4        83          77        9.95      ZA  2023-10-04 03:11:16

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                          City      Lat       Lng  Max Temp  \
# City_ID
# 0        palikir - national government center   6.9248  158.1611     88.54
# 1                                       lensk  60.7253  114.9278     36.72
# 2                                     dunedin -45.8742  170.5036     65.07
# 3                                    limassol  34.6750   33.0333     68.07
# 4                                richards bay -28.7830   32.0377     70.48
#
#          Humidity  Cloudiness  Wind Speed Country                 Date
# City_ID
# 0              70          75        5.75      FM  2023-10-04 03:11:15
# 1              94         100        8.99      RU  2023-10-04 03:11:15
# 2              27         100        3.42      NZ  2023-10-04 03:09:54
# 3              64           0        3.44      CY  2023-10-04 03:11:16
# 4              83          77        9.95      ZA  2023-10-04 03:11:16

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
lat = city_data_df["Lat"]
max_temp = city_data_df["Max Temp"]
plt.scatter(lat, max_temp)


# Incorporate the other graph properties
plt.grid(True)
plt.ylabel("Tempature (F)")
plt.xlabel("Latitude")
plt.title("Latitude vs Temperature")
           
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
lat = city_data_df["Lat"]
Humidity = city_data_df["Humidity"]
plt.scatter(lat, Humidity)


# Incorporate the other graph properties
plt.grid(True)
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.title("Latitude vs Humidity")
# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
lat = city_data_df["Lat"]
Cloudiness = city_data_df["Cloudiness"]
plt.scatter(lat, Humidity)


# Incorporate the other graph properties
plt.grid(True)
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.title("Latitude vs Cloudiness")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
lat = city_data_df["Lat"]
wind = city_data_df["Wind Speed"]
plt.scatter(lat, wind)


# Incorporate the other graph properties
plt.grid(True)
plt.ylabel("Wind Spped (m/s)")
plt.xlabel("Latitude")
plt.title("Latitude vs Wind Speed")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regression_plot(x_values, y_values):

    #Run linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    # Plot scatter plot
    plt.scatter(x_values,y_values)
    
    # Plot regression line
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,(10,10),fontsize=15,color="red")
    
    # Label plot
    plt.xlabel('Latitude')
    plt.ylabel('y_values')
    
    # Print r square value
    print(f"The r-value is: {rvalue**2}")
    
# Show plot
plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
north_df = city_data_df.loc[city_data_df['Lat']>= 0]

# Display sample data
north_df.head()
# Out:
#                                          City      Lat       Lng  Max Temp  \
# City_ID
# 0        palikir - national government center   6.9248  158.1611     88.54
# 1                                       lensk  60.7253  114.9278     36.72
# 3                                    limassol  34.6750   33.0333     68.07
# 5                                        yeed   4.5500   43.0333     77.79
# 8                                     udachny  66.4167  112.4000     26.46
#
#          Humidity  Cloudiness  Wind Speed Country                 Date
# City_ID
# 0              70          75        5.75      FM  2023-10-04 03:11:15
# 1              94         100        8.99      RU  2023-10-04 03:11:15
# 3              64           0        3.44      CY  2023-10-04 03:11:16
# 5              71         100       12.75      SO  2023-10-04 03:11:16
# 8              85         100       19.71      RU  2023-10-04 03:11:16

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
south_df = city_data_df.loc[city_data_df['Lat'] < 0]

# Display sample data
south_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2               dunedin -45.8742  170.5036     65.07        27         100
# 4          richards bay -28.7830   32.0377     70.48        83          77
# 6             adamstown -25.0660 -130.1015     68.20        77         100
# 7        margaret river -33.9500  115.0667     60.78        63         100
# 10             waitangi -43.9535 -176.5597     50.83        75          18
#
#          Wind Speed Country                 Date
# City_ID
# 2              3.42      NZ  2023-10-04 03:09:54
# 4              9.95      ZA  2023-10-04 03:11:16
# 6             16.67      PN  2023-10-04 03:11:16
# 7              6.89      AU  2023-10-04 03:11:16
# 10             5.99      NZ  2023-10-04 03:11:16

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = north_df['Lat']
y_values = north_df['Max Temp']

north_stats = linear_regression_plot(x_values, y_values)
north_stats
# Out:
# The r-value is: 0.7665799897666491

# %%
# Linear regression on Southern Hemisphere
x_values = south_df['Lat']
y_values = south_df['Max Temp']

south_stats = linear_regression_plot(x_values, y_values)
south_stats
# Out:
# The r-value is: 0.6061192393089048

# %% [markdown]
# **Discussion about the linear relationship:**
# - countries closer to the equator tend to have a warmer max temp
# - the further you move from the equator, whether it is north or south, the max tempature drops

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = north_df['Lat']
y_values = north_df['Humidity']

north_stats = linear_regression_plot(x_values, y_values)
north_stats
# Out:
# The r-value is: 0.0027368365081351757

# %%
# Southern Hemisphere
x_values = south_df['Lat']
y_values = south_df['Humidity']

south_stats = linear_regression_plot(x_values, y_values)
south_stats
# Out:
# The r-value is: 0.0003740792427673195

# %% [markdown]
# **Discussion about the linear relationship:** - The lines of both graphs have similar slops\n",
#    - The slopes are postive and increase
#    - It is interesting that the further north you go, the
#    humditiy increasing. it is not linked to the equator

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = north_df['Lat']
y_values = north_df['Cloudiness']

north_stats = linear_regression_plot(x_values, y_values)
north_stats
# Out:
# The r-value is: 0.005044042659372878

# %%
# Southern Hemisphere
x_values = south_df['Lat']
y_values = south_df['Cloudiness']

south_stats = linear_regression_plot(x_values, y_values)
south_stats
# Out:
# The r-value is: 0.023780290969159297

# %% [markdown]
# **Discussion about the linear relationship:**
# - The lines are almost identical.
# - The line does not follow the path of the points at
# - Cloudness appears to be common in places, no matter if you are close to the equator vs north/south

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = north_df['Lat']
y_values = north_df['Wind Speed']

north_stats = linear_regression_plot(x_values, y_values)
north_stats
# Out:
# The r-value is: 0.03312910083053812

# %%
# Southern Hemisphere
x_values = south_df['Lat']
y_values = south_df['Wind Speed']

south_stats = linear_regression_plot(x_values, y_values)
south_stats
# Out:
# The r-value is: 0.01180801261648792

# %% [markdown]
# **Discussion about the linear relationship:**
#  - The wind speed is higher the further away you are from the equator
#  - The trend for wind speed from the data set is between 15 - 5 mph
#  -
